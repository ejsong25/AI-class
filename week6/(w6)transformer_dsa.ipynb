# %% [markdown]
# # Week6
# Transformer

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('DSA_features.csv')

df.head()
# Out:
#    T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 0     7.975714      8.1605      7.6823    0.014395    0.119981    -0.023319
# 1     7.978250      8.1763      7.8472    0.007551    0.086896     0.552416
# 2     7.970894      8.0860      7.8470    0.003092    0.055603     0.100538
# 3     7.938412      8.1083      7.6901    0.003763    0.061343    -0.231914
# 4     7.908930      8.1305      7.8322    0.001741    0.041731     2.042285
#
#    T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  LL_ymag_std  \
# 0     1.083150      1.1832     0.99744    0.002208  ...     0.000792
# 1     1.140865      1.2129     1.05810    0.000784  ...     0.000860
# 2     1.140962      1.2128     1.07960    0.000508  ...     0.000762
# 3     1.165260      1.3170     1.07870    0.002173  ...     0.000735
# 4     1.187504      1.2574     1.09450    0.000662  ...     0.000824
#
#    LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min   LL_zmag_var  \
# 0      0.177075     -0.057119    -0.054963    -0.059241  6.778722e-07
# 1     -0.286918     -0.057268    -0.054945    -0.059589  7.032302e-07
# 2     -0.134430     -0.057068    -0.054711    -0.059065  6.268222e-07
# 3      0.021485     -0.056422    -0.053670    -0.058310  8.011245e-07
# 4     -0.148229     -0.055801    -0.053313    -0.057815  6.853423e-07
#
#    LL_zmag_std  LL_zmag_skew  activity  people
# 0     0.000823      0.036729   sitting      p1
# 1     0.000839      0.347471   sitting      p1
# 2     0.000792      0.045579   sitting      p1
# 3     0.000895      0.240690   sitting      p1
# 4     0.000828      0.258429   sitting      p1
#
# [5 rows x 272 columns]

# %%
# 관심있는 3가지 activity 추출
df = df.loc[df['activity'].isin(['lyingRigh', 'lyingBack', 'jumping'])]
df['activity'].value_counts()
# Out:
# activity
# lyingBack    480
# lyingRigh    480
# jumping      480
# Name: count, dtype: int64

# %%
abnormal = df[df.activity == 'jumping']
normal = df[df.activity.isin(['lyingRigh', 'lyingBack'])]

abnormal.shape, normal.shape
# Out:
# ((480, 272), (960, 272))

# %%
df['class'] = df['activity'].apply(lambda x: 'normal' if x.startswith('lying') else 'abnormal')
df.columns
# Out:
# Index(['T_xacc_mean', 'T_xacc_max', 'T_xacc_min', 'T_xacc_var', 'T_xacc_std',
#        'T_xacc_skew', 'T_yacc_mean', 'T_yacc_max', 'T_yacc_min', 'T_yacc_var',
#        ...
#        'LL_ymag_skew', 'LL_zmag_mean', 'LL_zmag_max', 'LL_zmag_min',
#        'LL_zmag_var', 'LL_zmag_std', 'LL_zmag_skew', 'activity', 'people',
#        'class'],
#       dtype='object', length=273)

# %%
data = df.drop(['activity', 'people'], axis=1)
data.head()
# Out:
#      T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  T_xacc_skew  \
# 960    -4.834646     -4.7185     -4.9049    0.001124    0.033529     0.632141
# 961    -4.780810     -4.5850     -4.8833    0.003948    0.062835     1.052880
# 962    -4.804400     -4.7037     -4.8755    0.001482    0.038496     0.735226
# 963    -4.750563     -4.5696     -4.8977    0.004447    0.066683     0.710263
# 964    -4.774916     -4.6741     -4.8457    0.001080    0.032868     0.324779
#
#      T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...   LL_ymag_var  \
# 960    -0.501018    -0.41744    -0.59561    0.001016  ...  9.725263e-07
# 961    -0.480601    -0.40372    -0.63184    0.001297  ...  6.211659e-07
# 962    -0.493925    -0.42616    -0.59561    0.000863  ...  4.579046e-07
# 963    -0.437358    -0.30877    -0.55225    0.003587  ...  4.703523e-07
# 964    -0.459456    -0.38900    -0.53714    0.001059  ...  5.467316e-07
#
#      LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 960     0.000986      0.074676     -0.532664     -0.52993     -0.53521
# 961     0.000788     -0.181526     -0.531169     -0.52940     -0.53365
# 962     0.000677     -0.263115     -0.530569     -0.52873     -0.53222
# 963     0.000686     -0.060925     -0.531167     -0.52962     -0.53283
# 964     0.000739      0.335811     -0.529804     -0.52706     -0.53251
#
#       LL_zmag_var  LL_zmag_std  LL_zmag_skew   class
# 960  9.585668e-07     0.000979     -0.193301  normal
# 961  7.608973e-07     0.000872     -0.372381  normal
# 962  5.160537e-07     0.000718      0.185587  normal
# 963  4.975523e-07     0.000705     -0.145321  normal
# 964  1.292131e-06     0.001137     -0.026271  normal
#
# [5 rows x 271 columns]

# %% [markdown]
# #### Train, Test data preparation

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# normal Train data
X_train = normal.drop(['activity', 'people'], axis=1)

# mixed test data
X_mix = df.iloc[:, :-1].drop(['activity', 'people'], axis=1).values
y_mix = df.iloc[:, -1].values
y_mix = le.fit_transform(y_mix)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_mix = ss.transform(X_mix)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_mix_train, X_min_test, y_mix_train, y_mix_test = train_test_split(
    X_mix, y_mix, test_size=0.2, random_state=42
)

# %%
import numpy as np
import keras
from keras import layers

X_train = X_mix_train.reshape((X_mix_train.shape[0], X_mix_train.shape[1], 1))
X_test = X_min_test.reshape((X_min_test.shape[0], X_min_test.shape[1], 1))

n_classes = len(np.unique(y_mix_train)) # 2

# %%
X_train.shape, y_mix_train.shape
# Out:
# ((1152, 270, 1), (1152,))

# %%
X_test.shape, y_mix_test.shape
# Out:
# ((288, 270, 1), (288,))

# %% [markdown]
# #### Construct Model

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):

    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(input_shape,
                head_size,
                num_heads,
                ff_dim,
                num_transformer_blocks,
                mlp_units,
                dropout=0,
                mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs

    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)

    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    return keras.Model(inputs, outputs)

# %%
input_shape = X_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["accuracy"],
)

# %%
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

history = model.fit(
    X_train,
    y_mix_train,
    validation_split=0.2,
    epochs=150,
    batch_size=64,
    callbacks=callbacks,
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 270, 1)         │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_5    │ (None, 270, 1)         │          7,169 │ input_layer_2[0][0],   │
# │ (MultiHeadAttention)      │                        │                │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_16 (Dropout)      │ (None, 270, 1)         │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_9     │ (None, 270, 1)         │              2 │ dropout_16[0][0]       │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 270, 1)         │              0 │ layer_normalization_9… │
# │                           │                        │                │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_9 (Conv1D)         │ (None, 270, 4)         │              8 │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_17 (Dropout)      │ (None, 270, 4)         │              0 │ conv1d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_10 (Conv1D)        │ (None, 270, 1)         │              5 │ dropout_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_10    │ (None, 270, 1)         │              2 │ conv1d_10[0][0]        │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_10 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_9[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_6    │ (None, 270, 1)         │          7,169 │ add_10[0][0],          │
# │ (MultiHeadAttention)      │                        │                │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_19 (Dropout)      │ (None, 270, 1)         │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_11    │ (None, 270, 1)         │              2 │ dropout_19[0][0]       │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_11 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_10[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_11 (Conv1D)        │ (None, 270, 4)         │              8 │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_20 (Dropout)      │ (None, 270, 4)         │              0 │ conv1d_11[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_12 (Conv1D)        │ (None, 270, 1)         │              5 │ dropout_20[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_12    │ (None, 270, 1)         │              2 │ conv1d_12[0][0]        │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_11[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_7    │ (None, 270, 1)         │          7,169 │ add_12[0][0],          │
# │ (MultiHeadAttention)      │                        │                │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_22 (Dropout)      │ (None, 270, 1)         │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_13    │ (None, 270, 1)         │              2 │ dropout_22[0][0]       │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_13 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_13 (Conv1D)        │ (None, 270, 4)         │              8 │ add_13[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_23 (Dropout)      │ (None, 270, 4)         │              0 │ conv1d_13[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_14 (Conv1D)        │ (None, 270, 1)         │              5 │ dropout_23[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_14    │ (None, 270, 1)         │              2 │ conv1d_14[0][0]        │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_14 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_13[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_8    │ (None, 270, 1)         │          7,169 │ add_14[0][0],          │
# │ (MultiHeadAttention)      │                        │                │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_25 (Dropout)      │ (None, 270, 1)         │              0 │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_15    │ (None, 270, 1)         │              2 │ dropout_25[0][0]       │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_15 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_14[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_15 (Conv1D)        │ (None, 270, 4)         │              8 │ add_15[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_26 (Dropout)      │ (None, 270, 4)         │              0 │ conv1d_15[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_16 (Conv1D)        │ (None, 270, 1)         │              5 │ dropout_26[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ layer_normalization_16    │ (None, 270, 1)         │              2 │ conv1d_16[0][0]        │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_16 (Add)              │ (None, 270, 1)         │              0 │ layer_normalization_1… │
# │                           │                        │                │ add_15[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling1d… │ (None, 1)              │              0 │ add_16[0][0]           │
# │ (GlobalAveragePooling1D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 128)            │            256 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_27 (Dropout)      │ (None, 128)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1)              │            129 │ dropout_27[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 29,129 (113.79 KB)
#  Trainable params: 29,129 (113.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 2s/step - accuracy: 0.5701 - loss: 3.7133 - val_accuracy: 0.5325 - val_loss: 1.4820
# Epoch 2/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.6745 - loss: 3.7573 - val_accuracy: 0.9264 - val_loss: 0.5944
# Epoch 3/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.7353 - loss: 2.4041 - val_accuracy: 0.9351 - val_loss: 0.4585
# Epoch 4/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.7871 - loss: 1.9357 - val_accuracy: 0.9437 - val_loss: 0.4379
# Epoch 5/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.8495 - loss: 1.7324 - val_accuracy: 0.9654 - val_loss: 0.4294
# Epoch 6/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.8611 - loss: 1.5370 - val_accuracy: 0.9784 - val_loss: 0.4231
# Epoch 7/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9088 - loss: 1.2495 - val_accuracy: 0.9784 - val_loss: 0.4176
# Epoch 8/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9284 - loss: 0.7895 - val_accuracy: 0.9827 - val_loss: 0.4121
# Epoch 9/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9222 - loss: 1.1569 - val_accuracy: 0.9870 - val_loss: 0.4065
# Epoch 10/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - accuracy: 0.9359 - loss: 0.9831 - val_accuracy: 0.9870 - val_loss: 0.4009
# Epoch 11/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.9377 - loss: 0.8522 - val_accuracy: 0.9870 - val_loss: 0.3950
# Epoch 12/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.9340 - loss: 0.7661 - val_accuracy: 0.9870 - val_loss: 0.3890
# Epoch 13/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9547 - loss: 0.7209 - val_accuracy: 0.9870 - val_loss: 0.3827
# Epoch 14/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9439 - loss: 0.7597 - val_accuracy: 0.9870 - val_loss: 0.3763
# Epoch 15/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9717 - loss: 0.4847 - val_accuracy: 0.9870 - val_loss: 0.3696
# Epoch 16/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9536 - loss: 0.7331 - val_accuracy: 0.9913 - val_loss: 0.3626
# Epoch 17/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9522 - loss: 0.7100 - val_accuracy: 0.9913 - val_loss: 0.3554
# Epoch 18/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9693 - loss: 0.5904 - val_accuracy: 0.9913 - val_loss: 0.3480
# Epoch 19/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9742 - loss: 0.4441 - val_accuracy: 0.9913 - val_loss: 0.3404
# Epoch 20/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9714 - loss: 0.4665 - val_accuracy: 0.9913 - val_loss: 0.3325
# Epoch 21/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9819 - loss: 0.3770 - val_accuracy: 0.9913 - val_loss: 0.3246
# Epoch 22/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9697 - loss: 0.4582 - val_accuracy: 0.9913 - val_loss: 0.3165
# Epoch 23/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9729 - loss: 0.4797 - val_accuracy: 0.9913 - val_loss: 0.3082
# Epoch 24/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9810 - loss: 0.4098 - val_accuracy: 0.9913 - val_loss: 0.2999
# Epoch 25/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9763 - loss: 0.4085 - val_accuracy: 0.9913 - val_loss: 0.2915
# Epoch 26/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9814 - loss: 0.4042 - val_accuracy: 0.9913 - val_loss: 0.2831
# Epoch 27/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9805 - loss: 0.3871 - val_accuracy: 0.9913 - val_loss: 0.2746
# Epoch 28/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9792 - loss: 0.4033 - val_accuracy: 0.9913 - val_loss: 0.2661
# Epoch 29/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.9814 - loss: 0.3635 - val_accuracy: 0.9913 - val_loss: 0.2577
# Epoch 30/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9835 - loss: 0.2933 - val_accuracy: 0.9913 - val_loss: 0.2492
# Epoch 31/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9880 - loss: 0.3238 - val_accuracy: 0.9913 - val_loss: 0.2407
# Epoch 32/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9749 - loss: 0.4333 - val_accuracy: 0.9913 - val_loss: 0.2324
# Epoch 33/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9795 - loss: 0.4100 - val_accuracy: 0.9913 - val_loss: 0.2242
# Epoch 34/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9763 - loss: 0.3432 - val_accuracy: 0.9913 - val_loss: 0.2162
# Epoch 35/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9892 - loss: 0.2606 - val_accuracy: 0.9913 - val_loss: 0.2082
# Epoch 36/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9849 - loss: 0.3133 - val_accuracy: 0.9913 - val_loss: 0.2005
# Epoch 37/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9923 - loss: 0.2232 - val_accuracy: 0.9913 - val_loss: 0.1928
# Epoch 38/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9913 - loss: 0.2160 - val_accuracy: 0.9913 - val_loss: 0.1854
# Epoch 39/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9889 - loss: 0.2363 - val_accuracy: 0.9913 - val_loss: 0.1780
# Epoch 40/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9823 - loss: 0.2311 - val_accuracy: 0.9913 - val_loss: 0.1710
# Epoch 41/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.9935 - loss: 0.2084 - val_accuracy: 0.9913 - val_loss: 0.1640
# Epoch 42/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9860 - loss: 0.2363 - val_accuracy: 0.9913 - val_loss: 0.1574
# Epoch 43/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9896 - loss: 0.1853 - val_accuracy: 0.9913 - val_loss: 0.1509
# Epoch 44/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9908 - loss: 0.2099 - val_accuracy: 0.9913 - val_loss: 0.1448
# Epoch 45/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9873 - loss: 0.2056 - val_accuracy: 0.9913 - val_loss: 0.1388
# Epoch 46/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.9874 - loss: 0.1645 - val_accuracy: 0.9913 - val_loss: 0.1330
# Epoch 47/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9902 - loss: 0.1660 - val_accuracy: 0.9913 - val_loss: 0.1275
# Epoch 48/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9954 - loss: 0.1461 - val_accuracy: 0.9913 - val_loss: 0.1221
# Epoch 49/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9923 - loss: 0.1742 - val_accuracy: 0.9913 - val_loss: 0.1170
# Epoch 50/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9936 - loss: 0.1321 - val_accuracy: 0.9913 - val_loss: 0.1121
# Epoch 51/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9957 - loss: 0.1190 - val_accuracy: 0.9913 - val_loss: 0.1075
# Epoch 52/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9934 - loss: 0.1227 - val_accuracy: 0.9913 - val_loss: 0.1029
# Epoch 53/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9921 - loss: 0.1311 - val_accuracy: 0.9913 - val_loss: 0.0986
# Epoch 54/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9907 - loss: 0.1238 - val_accuracy: 0.9913 - val_loss: 0.0945
# Epoch 55/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9931 - loss: 0.1065 - val_accuracy: 0.9913 - val_loss: 0.0906
# Epoch 56/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 141ms/step - accuracy: 0.9904 - loss: 0.1301 - val_accuracy: 0.9913 - val_loss: 0.0868
# Epoch 57/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9948 - loss: 0.0962 - val_accuracy: 0.9957 - val_loss: 0.0833
# Epoch 58/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9918 - loss: 0.1134 - val_accuracy: 0.9957 - val_loss: 0.0799
# Epoch 59/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9842 - loss: 0.1272 - val_accuracy: 0.9957 - val_loss: 0.0766
# Epoch 60/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9879 - loss: 0.1092 - val_accuracy: 0.9957 - val_loss: 0.0735
# Epoch 61/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9907 - loss: 0.1057 - val_accuracy: 0.9957 - val_loss: 0.0705
# Epoch 62/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9942 - loss: 0.0793 - val_accuracy: 0.9957 - val_loss: 0.0677
# Epoch 63/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9946 - loss: 0.0805 - val_accuracy: 0.9957 - val_loss: 0.0650
# Epoch 64/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9925 - loss: 0.0742 - val_accuracy: 0.9957 - val_loss: 0.0625
# Epoch 65/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9886 - loss: 0.0833 - val_accuracy: 0.9957 - val_loss: 0.0600
# Epoch 66/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9945 - loss: 0.0687 - val_accuracy: 0.9957 - val_loss: 0.0577
# Epoch 67/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9953 - loss: 0.0656 - val_accuracy: 0.9957 - val_loss: 0.0555
# Epoch 68/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9966 - loss: 0.0626 - val_accuracy: 0.9957 - val_loss: 0.0534
# Epoch 69/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9982 - loss: 0.0567 - val_accuracy: 0.9957 - val_loss: 0.0514
# Epoch 70/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9949 - loss: 0.0715 - val_accuracy: 0.9957 - val_loss: 0.0495
# Epoch 71/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9966 - loss: 0.0531 - val_accuracy: 0.9957 - val_loss: 0.0477
# Epoch 72/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9946 - loss: 0.0964 - val_accuracy: 0.9957 - val_loss: 0.0460
# Epoch 73/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9960 - loss: 0.0542 - val_accuracy: 0.9957 - val_loss: 0.0443
# Epoch 74/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9953 - loss: 0.0494 - val_accuracy: 0.9957 - val_loss: 0.0428
# Epoch 75/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9941 - loss: 0.0814 - val_accuracy: 0.9957 - val_loss: 0.0413
# Epoch 76/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9951 - loss: 0.0439 - val_accuracy: 0.9957 - val_loss: 0.0399
# Epoch 77/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9973 - loss: 0.0469 - val_accuracy: 0.9957 - val_loss: 0.0385
# Epoch 78/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9950 - loss: 0.0487 - val_accuracy: 0.9957 - val_loss: 0.0372
# Epoch 79/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9983 - loss: 0.0393 - val_accuracy: 0.9957 - val_loss: 0.0360
# Epoch 80/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9956 - loss: 0.1049 - val_accuracy: 0.9957 - val_loss: 0.0349
# Epoch 81/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9945 - loss: 0.0431 - val_accuracy: 0.9957 - val_loss: 0.0338
# Epoch 82/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9935 - loss: 0.0680 - val_accuracy: 0.9957 - val_loss: 0.0327
# Epoch 83/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9985 - loss: 0.0343 - val_accuracy: 0.9957 - val_loss: 0.0317
# Epoch 84/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9968 - loss: 0.0365 - val_accuracy: 0.9957 - val_loss: 0.0307
# Epoch 85/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9959 - loss: 0.0436 - val_accuracy: 0.9957 - val_loss: 0.0298
# Epoch 86/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9942 - loss: 0.0470 - val_accuracy: 0.9957 - val_loss: 0.0289
# Epoch 87/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9951 - loss: 0.0413 - val_accuracy: 0.9957 - val_loss: 0.0281
# Epoch 88/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9968 - loss: 0.0406 - val_accuracy: 0.9957 - val_loss: 0.0273
# Epoch 89/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 129ms/step - accuracy: 0.9900 - loss: 0.0358 - val_accuracy: 0.9957 - val_loss: 0.0265
# Epoch 90/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9970 - loss: 0.0297 - val_accuracy: 0.9957 - val_loss: 0.0258
# Epoch 91/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9956 - loss: 0.0771 - val_accuracy: 0.9957 - val_loss: 0.0251
# Epoch 92/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9968 - loss: 0.0478 - val_accuracy: 0.9957 - val_loss: 0.0244
# Epoch 93/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9974 - loss: 0.0286 - val_accuracy: 0.9957 - val_loss: 0.0238
# Epoch 94/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9944 - loss: 0.0273 - val_accuracy: 0.9957 - val_loss: 0.0231
# Epoch 95/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9953 - loss: 0.0279 - val_accuracy: 0.9957 - val_loss: 0.0225
# Epoch 96/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9968 - loss: 0.0269 - val_accuracy: 0.9957 - val_loss: 0.0220
# Epoch 97/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9961 - loss: 0.0291 - val_accuracy: 0.9957 - val_loss: 0.0214
# Epoch 98/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9988 - loss: 0.0213 - val_accuracy: 0.9957 - val_loss: 0.0209
# Epoch 99/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9930 - loss: 0.0606 - val_accuracy: 0.9957 - val_loss: 0.0204
# Epoch 100/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9963 - loss: 0.0247 - val_accuracy: 0.9957 - val_loss: 0.0199
# Epoch 101/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9943 - loss: 0.0351 - val_accuracy: 0.9957 - val_loss: 0.0194
# Epoch 102/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9956 - loss: 0.0233 - val_accuracy: 0.9957 - val_loss: 0.0189
# Epoch 103/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - accuracy: 0.9968 - loss: 0.0250 - val_accuracy: 0.9957 - val_loss: 0.0185
# Epoch 104/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9953 - loss: 0.0215 - val_accuracy: 0.9957 - val_loss: 0.0181
# Epoch 105/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9948 - loss: 0.0225 - val_accuracy: 0.9957 - val_loss: 0.0177
# Epoch 106/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9976 - loss: 0.0208 - val_accuracy: 0.9957 - val_loss: 0.0173
# Epoch 107/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9960 - loss: 0.0197 - val_accuracy: 0.9957 - val_loss: 0.0169
# Epoch 108/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9973 - loss: 0.0186 - val_accuracy: 0.9957 - val_loss: 0.0166
# Epoch 109/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9972 - loss: 0.0187 - val_accuracy: 0.9957 - val_loss: 0.0162
# Epoch 110/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9934 - loss: 0.0733 - val_accuracy: 0.9957 - val_loss: 0.0159
# Epoch 111/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9983 - loss: 0.0158 - val_accuracy: 0.9957 - val_loss: 0.0156
# Epoch 112/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9945 - loss: 0.0329 - val_accuracy: 0.9957 - val_loss: 0.0152
# Epoch 113/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9983 - loss: 0.0151 - val_accuracy: 0.9957 - val_loss: 0.0149
# Epoch 114/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9972 - loss: 0.0169 - val_accuracy: 0.9957 - val_loss: 0.0147
# Epoch 115/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9940 - loss: 0.0183 - val_accuracy: 0.9957 - val_loss: 0.0144
# Epoch 116/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9970 - loss: 0.0199 - val_accuracy: 0.9957 - val_loss: 0.0141
# Epoch 117/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9967 - loss: 0.0154 - val_accuracy: 0.9957 - val_loss: 0.0138
# Epoch 118/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9967 - loss: 0.0160 - val_accuracy: 0.9957 - val_loss: 0.0136
# Epoch 119/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9955 - loss: 0.0172 - val_accuracy: 0.9957 - val_loss: 0.0133
# Epoch 120/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9966 - loss: 0.0162 - val_accuracy: 0.9957 - val_loss: 0.0131
# Epoch 121/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9949 - loss: 0.0151 - val_accuracy: 0.9957 - val_loss: 0.0128
# Epoch 122/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9984 - loss: 0.0116 - val_accuracy: 0.9957 - val_loss: 0.0126
# Epoch 123/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9946 - loss: 0.0170 - val_accuracy: 0.9957 - val_loss: 0.0124
# Epoch 124/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9930 - loss: 0.0177 - val_accuracy: 0.9957 - val_loss: 0.0122
# Epoch 125/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9966 - loss: 0.0175 - val_accuracy: 0.9957 - val_loss: 0.0120
# Epoch 126/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 139ms/step - accuracy: 0.9953 - loss: 0.0144 - val_accuracy: 0.9957 - val_loss: 0.0118
# Epoch 127/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9925 - loss: 0.0167 - val_accuracy: 0.9957 - val_loss: 0.0116
# Epoch 128/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.9974 - loss: 0.0141 - val_accuracy: 0.9957 - val_loss: 0.0114
# Epoch 129/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9971 - loss: 0.0124 - val_accuracy: 0.9957 - val_loss: 0.0113
# Epoch 130/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9969 - loss: 0.0106 - val_accuracy: 0.9957 - val_loss: 0.0111
# Epoch 131/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9972 - loss: 0.0117 - val_accuracy: 0.9957 - val_loss: 0.0109
# Epoch 132/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - accuracy: 0.9941 - loss: 0.0141 - val_accuracy: 0.9957 - val_loss: 0.0108
# Epoch 133/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9955 - loss: 0.0132 - val_accuracy: 0.9957 - val_loss: 0.0106
# Epoch 134/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.9973 - loss: 0.0113 - val_accuracy: 0.9957 - val_loss: 0.0104
# Epoch 135/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9944 - loss: 0.0143 - val_accuracy: 0.9957 - val_loss: 0.0103
# Epoch 136/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9973 - loss: 0.0109 - val_accuracy: 0.9957 - val_loss: 0.0102
# Epoch 137/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9972 - loss: 0.0105 - val_accuracy: 0.9957 - val_loss: 0.0100
# Epoch 138/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9936 - loss: 0.0138 - val_accuracy: 0.9957 - val_loss: 0.0099
# Epoch 139/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.9942 - loss: 0.0234 - val_accuracy: 0.9957 - val_loss: 0.0097
# Epoch 140/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - accuracy: 0.9953 - loss: 0.0201 - val_accuracy: 0.9957 - val_loss: 0.0096
# Epoch 141/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - accuracy: 0.9989 - loss: 0.0096 - val_accuracy: 0.9957 - val_loss: 0.0095
# Epoch 142/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9966 - loss: 0.0106 - val_accuracy: 0.9957 - val_loss: 0.0094
# Epoch 143/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9977 - loss: 0.0091 - val_accuracy: 0.9957 - val_loss: 0.0092
# Epoch 144/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 0.9957 - val_loss: 0.0091
# Epoch 145/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 0.9957 - val_loss: 0.0090
# Epoch 146/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9965 - loss: 0.0102 - val_accuracy: 0.9957 - val_loss: 0.0089
# Epoch 147/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9957 - val_loss: 0.0088
# Epoch 148/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - accuracy: 0.9932 - loss: 0.0261 - val_accuracy: 0.9957 - val_loss: 0.0087
# Epoch 149/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9931 - loss: 0.0123 - val_accuracy: 0.9957 - val_loss: 0.0086
# Epoch 150/150
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9971 - loss: 0.0090 - val_accuracy: 0.9957 - val_loss: 0.0085

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = model.predict(X_test)
y_pred = (y_pred>=0.5).astype(int)
print(classification_report(y_mix_test, y_pred))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        93
#            1       1.00      1.00      1.00       195
#
#     accuracy                           1.00       288
#    macro avg       1.00      1.00      1.00       288
# weighted avg       1.00      1.00      1.00       288

# %%
model.evaluate(X_test, y_mix_test, verbose=1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 1.0000 - loss: 0.0051
# [0.0053171138279139996, 1.0]
